# %%
import pickle as pkl
import torch

# %%
fp = "/home/jienihu/sc/SLformer/data/saved_data/map/gene2sent_n10.pkl"

# %%
with open(fp, 'rb') as f:
    gene_sent_map = pkl.load(f)

# %%
print(list(gene_sent_map[0].keys())[:10])
print(gene_sent_map[0][885])
print(type(gene_sent_map[0][885]))
print(torch.tensor(gene_sent_map[0][885]))
# Out:
# [2711, 13276, 885, 7967, 97, 808, 10820, 4660, 8637, 2687]
# [886, 6071, 10899, 9891, 5404, 10992, 7656, 6047, 5101, 7708, 2501]
# <class 'list'>
# tensor([  886,  6071, 10899,  9891,  5404, 10992,  7656,  6047,  5101,  7708,
#          2501])
